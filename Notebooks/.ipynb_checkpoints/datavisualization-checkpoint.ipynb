# %% [markdown]
# # Data Visualization
#
# In this notebook, we will visualize the data comparing and contrasting the different MSAs for analysis.

# %% [markdown]
# ## Table of Contents
# * contents
#
# ## Notebooks
# * [Overview Notebook](airpollution.ipynb)
# * [Processing Notebook](dataprocessing.ipynb)
# * [Analysis Notebook](data-analysis.ipynb)

# %% [markdown]
# ## Accessing Functions
#
# Here, we simply run another notebook that contains all of the functions we will be using.

# %%
# %run dataprocessing.ipynb

# %% [markdown]
# ### Graphing The Data
#
# Now it's time to graph the data! Below are the core geographical areas which you can view the graphs of for both ozone trends and particulate matter trends:
# table of contents to take you to each area

# %% [markdown]
# ### New York-Newark-Jersey City (NY-NJ-PA)

# %%
aqi_plot(ny_nj_pa)
production(ny_nj_pa_production, 'NY-NJ-PA Production')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ae5310540fbd> in <module>
#       1 aqi_plot(ny_nj_pa)
# ----> 2 production(ny_nj_pa_production, 'NY-NJ-PA Production')
#
# <ipython-input-1-f214aa63adf3> in production(x, z)
#     139     plt.plot(time, transport_equipment)
#     140     plt.plot(time, machinery)
# --> 141     plt.plot(time, chemical_products)
#     142     plt.plot(time, newsprint_paper)
#     143     plt.plot(time, printed_products)
#
# NameError: name 'chemical_products' is not defined

# %% [markdown]
# ### Los Angeles-Long Beach-Anaheim (CA)

# %%
aqi_plot(ca)
production(ca_production, 'CA Production')

# %% [markdown]
# ### Chicago-Naperville-Elgin (IL-IN-WI)

# %%
aqi_plot(il_in_wi)
production(il_in_wi_production, 'IL-IN-WI Production')

# %% [markdown]
# ### Dallas-Fort Worth-Arlington (TX)

# %%
aqi_plot(tx)
production(tx_production, 'TX Production')

# %% [markdown]
# ### Washington-Arlington-Alexandria (DC-VA-MD-WV)

# %%
aqi_plot(dc_va_md_wv)
production(dc_va_md_wv_production, 'DC-VA-MD-WV Production')

# %% [markdown]
# ### Miami-Fort Lauderdale-West Palm Beach (FL)

# %%
aqi_plot(fl)
production(fl_production, 'FL Production')

# %% [markdown]
# ### Philadelphia-Camden-Wilmington (PA-NJ-DE-MD)

# %%
aqi_plot(pa_nj_de_md)
production(pa_nj_de_md_production, 'PA-NJ-DE-MD Production')

# %% [markdown]
# ### Atlanta-Sandy Springs-Roswell (GA)

# %%
aqi_plot(ga)
production(ga_production, 'GA Production')

# %% [markdown]
# ### Phoenix-Mesa-Scottsdale (AZ)

# %%
aqi_plot(az)
production(az_production, 'AZ Production')

# %% [markdown]
# ### Boston-Cambridge-Newton (MA-NH)

# %%
aqi_plot(ma_nh)
production(ma_nh_production, 'MA-NH Production')

# %% [markdown]
# ### Detroit-Warren-Dearborn (MI)

# %%
aqi_plot(mi)
production(mi_production, 'MI Production')

# %% [markdown]
# ### Seattle-Tacoma-Bellevue (WA)

# %%
aqi_plot(wa)
production(wa_production, 'WA Production')

# %% [markdown]
# ### Minneapolis-St. Paul-Bloomington (MN-WI)

# %%
aqi_plot(mn_wi)
production(mn_wi_production, 'MN-WI Production')

# %% [markdown]
# ### Denver-Aurora-Lakewood (CO)

# %%
aqi_plot(co)
production(co_production, 'CO Production')

# %% [markdown]
# ### St. Louis (MO-IL)

# %%
aqi_plot(mo_il)
production(mo_il_production, 'MO-IL Production')

# %% [markdown]
# ### All Graphs Together
#
# Now we're gonna display all air qualities on a single graph!

# %%
plot_all(areas)
