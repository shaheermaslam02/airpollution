# %% [markdown]
# # Data Visualization
#
# In this notebook, we will visualize the data comparing and contrasting the different MSAs for analysis.

# %% [markdown]
# # Notebooks
# * [Overview Notebook](airpollution.ipynb)
# * [Processing Notebook](dataprocessing.ipynb)
# * [Analysis Notebook](data-analysis.ipynb)

# %% [markdown]
# # Accessing Functions
#
# Here we simply run another notebook that contains all of the functions we will be using.

# %%
# %run dataprocessing.ipynb

# %% [markdown]
# # Visualizing the Data
#
# Now it's time to graph the data! We split it up by region due to the similarities in climate to keep the comparisons generally consistent.

# %% [markdown]
# # Northeast MSAs
#
# Here we visualize the New York Metro, Delaware Valley Metro, and Greater Boston Metro Areas.

# %% [markdown]
# ### Air Quality

# %%
aqi_plot(ny_nj_pa, ny_nj_pa_annual, 'New York Metro AQI')
aqi_plot(pa_nj_de_md, pa_nj_de_md_annual, 'Delaware Valley Metro AQI')
aqi_plot(ma_nh, ma_nh_annual, 'Greater Boston Metro AQI')
aqi_plot(dc_va_md_wv, dc_va_md_wv_annual, 'Washington D.C. Metro AQI')

# %% [markdown]
# ### Production

# %%
production_graph(ny_nj_pa_production, 'New York Metro Production')
production_graph(pa_nj_de_md_production, 'Delaware Valley Metro Production')
production_graph(ma_nh_production, 'Greater Boston Metro Production')
production_graph(dc_va_md_wv_production, 'Washington D.C. Metro Production')

# %% [markdown]
# ### 2020 Commuting Correlation Matrices

# %%
correlation(ny_nj_pa_mobility, 'New York Metro Commuting')
correlation(pa_nj_de_md_mobility, 'Delaware Valley Metro Commuting')
correlation(ma_nh_mobility, 'Greater Boston Metro Commuting')
correlation(dc_va_md_wv_mobility, 'Washington D.C. Metro Commuting')

# %% [markdown]
# # Central MSAs
#
# Here we visualize the Detroit Metro, Chicago Metro, Greater St. Louis, and Minneapolis Metro Areas.

# %% [markdown]
# ### Air Quality

# %%
aqi_plot(mi, mi_annual, 'Detroit Metro AQI')
aqi_plot(il_in_wi, il_in_wi_annual, 'Chicago Metro AQI')
aqi_plot(mo_il, mo_il_annual, 'Greater St. Louis Metro AQI')
aqi_plot(mn_wi, mn_wi_annual, 'Minneapolis Metro AQI')

# %% [markdown]
# ### Production

# %%
production_graph(mi_production, 'Detroit Metro Production')
production_graph(il_in_wi_production, 'Chicago Metro Production')
production_graph(mo_il_production, 'Greater St. Louis Metro Production')
production_graph(mn_wi_production, 'Minneapolis Metro Production')

# %% [markdown]
# ### 2020 Commuting Correlation Matrices

# %%
correlation(mi_mobility, 'Detroit Metro Commuting')
correlation(il_in_wi_mobility, 'Chicago Metro Commuting')
correlation(mo_il_mobility, 'Greater St. Louis Metro Commuting')

# %% [markdown]
# # Southeast MSAs
#
# Here we visualize the Miami and Atlanta Metro Areas.

# %% [markdown]
# ### Air Quality

# %%
aqi_plot(fl, fl_annual, 'Miami Metro AQI')
aqi_plot(ga, ga_annual, 'Atlanta Metro AQI')

# %% [markdown]
# ### Production

# %%
production_graph(fl_production, 'Miami Metro Production')
production_graph(ga_production, 'Atlanta Metro Production')

# %% [markdown]
# ### 2020 Commuting Correlation Matrices

# %%
correlation(fl_mobility, 'Miami Metro Commuting')
correlation(ga_mobility, 'Atlanta Metro Commuting')

# %% [markdown]
# # South/Southwest MSAs
#
# Here we visualize the Los Angeles Metro, Phoenix Metro, and Dallas Metro Areas.

# %% [markdown]
# ### Air Quality

# %%
aqi_plot(ca, ca_annual, 'Los Angeles Metro AQI')
aqi_plot(az, az_annual, 'Phoenix Metro AQI')
aqi_plot(tx, tx_annual, 'Dallas Metro AQI')

# %% [markdown]
# ### Production

# %%
production_graph(ca_production, 'Los Angeles Metro Production')
production_graph(az_production, 'Phoenix Metro Production')
production_graph(tx_production, 'Dallas Metro Production')

# %% [markdown]
# ### 2020 Commuting Correlation Matrices

# %%
correlation(ca_mobility, 'Los Angeles Metro Commuting')
correlation(az_mobility, 'Phoenix Metro Commuting')
correlation(tx_mobility, 'Dallas Metro Commuting')

# %% [markdown]
# # Outlier MSAs
#
# In terms of region and climate, these two metro areas are unique. Here we visualize the Denver and Seattle Metro Areas.

# %% [markdown]
# ### Air Quality

# %%
aqi_plot(co, co_annual, 'Denver Metro AQI')
aqi_plot(wa, wa_annual, 'Seattle Metro AQI')

# %% [markdown]
# ### Production

# %%
production_graph(co_production, 'Denver Metro Production')
production_graph(wa_production, 'Seattle Metro Production')

# %% [markdown]
# ### 2020 Commuting Correlation Matrices

# %%
correlation(co_mobility, 'Denver Metro Commuting')
correlation(wa_mobility, 'Seattle Metro Commuting')

# %% [markdown]
# # General Graphs and Simulations
#
# Here are our cross-metro comparisons and simulations!

# %% [markdown]
# ### Correlation Matrices

# %%
correlation(production, 'MSA Production Correlation')
correlation(mobility, 'MSA Air Quality and Commuting')

# %% [markdown]
# ### Simulations

# %%
simulation(msa, us)

# %%
energy_simulation(annual_energy_usage)
